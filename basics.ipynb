# %%
import pandas as pd

# %%
name = "Rameez Ehsan"
height= 5.5
age=  23
is_footballer=True
is_female=False

print(type(name))
print(type(height))
print(type(age))
print(type(is_footballer))
print(type(is_female))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>
# <class 'bool'>
# <class 'bool'>

# %%
name=(input("What is your name??"))
age=int(input("What is your age??"))
height=float(input("What is your height??"))

print("Your name is ", name)
print("Your height is", height)
print ("Your age is",age)
# Out:
# Your name is  Rameez
# Your height is 5.8
# Your age is 23

# %% [markdown]
# Getting User Information

# %%
print("Welcome to Registration System!")
print("-" * 40)

name=input("Please Enter Your Name:")
age=int(input("Enter your age:"))
height=float(input("Enter your height:"))
is_member = input("Are you a member? (yes/no): ").lower() == "yes"

#Display the collected information
print( "=" * 40)
print ("REGISTRATION SUMMARY")
print( "=" * 40)
print (f"Name:{name}")
print (f"Age:{age} Years Old")
print (f"Height is: {height} ft.")
print(f"Membership status: {is_member}")

print ("=" * 40)

# %% [markdown]
# Day 2 Python Gen AI.

# %%
points = int(input("Please Enter the number of points for this years Ballon d'or"))
if points >=500:
    print("Leo Messi won the Ballon D'or")
elif points >=300:
    print("Kylian Mbappe would have won it")
elif points >= 280:
    print("Harry Kane would have won it!!")
elif  points >= 200:
    print("Erling Haaland would have won it!!")
elif points >= 100:
    print("Vinicius Junior would have done it 10x")
else:
    print("INVALID INPUT")
# Out:
# Kylian Mbappe would have won it

# %%
age = int ( input("Please enter your age to check whether you caan vote in the upcoming elections or not?"))
has_voterid = True 
if age >= 18:
   if has_voterid:
    print("You can vote in the upcoming election!!")
   else:
    print ("You must be at least 18 years+ to vote")
 
else :
  print ("Go to government officials and ask them!!!!")
# Out:
# Go to government officials and ask them!!!!

# %%
players = [ "Julian Alvarez", "Alessandro Bastoni", "Alexander Sorloth", "Harry Kane" ,"Bernardo Silva" ]
players.append("Virgil Van Dijk")
players.insert(1,"Inigo Martinez")
players.insert(4,"Rameez Ehsan")
players.extend(["Leo Messi","Sadio Mane","Kylian Mbappe"])
players.remove("Rameez Ehsan")
# Out:
# 1

# %%
numbers = [1,2,3,7,4,5,7,89,56,34,56,7,8,9]
numbers.sort()
numbers.reverse()
print(5 in numbers)
print(numbers)
# Out:
# True
# [89, 56, 56, 34, 9, 8, 7, 7, 7, 5, 4, 3, 2, 1]

# %%
player = {
   "name" : "Leo Messi",
   "age" : 36,
   "club" : "Inter Miami",
   "is_retired" : False
}
player["Position"] = "Forward"
print(player["name"])
print(player["Position"])
player["age"] = 38
print(player.get("age"))
if player["is_retired"] == False:
    print("Leo Messi is Retired")
else:
    print ("Leo Messi Still plays for INTER MIAMI in the MSL AMERICA")
# Out:
# Leo Messi
# Forward
# 38
# Leo Messi is Retired
