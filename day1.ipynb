# %%
import pandas as pd

# %%
name = "Rameez Ehsan"
height= 5.5
age=  23
is_footballer=True
is_female=False

print(type(name))
print(type(height))
print(type(age))
print(type(is_footballer))
print(type(is_female))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>
# <class 'bool'>
# <class 'bool'>
